# %% [markdown]
# Machine Translation (MT)
#
# ### https://guardiancoder.com/category/nlp/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * NMT (Neural MT)

# %% [markdown]
# Neural machine translation (NMT) is an approach to machine translation that uses an artificial neural network to predict the likelihood of a sequence of words, typically modeling entire sentences in a single integrated model.

# %% [markdown]
# # Transformers
#
# The encoder and decoder are key components of NMT architectures.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # UniDirectional vs Bi-directional LSTM model

# %% [markdown]
# # Attention mechanism
#
# But then, the challenge then becomes, which word do we need to focus on in a sequence?
# the resulting architecture then embeds this Attention mechanism in between the Encoder and Decoder:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# =======================================================================

# %% [markdown]
# # Google Translate
#
# #### API  for Language Translation

# %%
#pip install googletrans==4.0.0rc1

# %%
import googletrans

print("supported languages " , googletrans.LANGUAGES)
# Out:
# supported languages  {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 
# ...

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
result = translator.translate('Its going to rain today in australia', src='en', dest='hi')

# %% [markdown]
# ### this is an image to show errors
#
#
# ![image.png](attachment:image.png)

# %%
print(result.src)
print(result.dest)
print(result.text)
# Out:
# en
# hi
# ऑस्ट्रेलिया में आज बारिश होने वाली है

# %% [markdown]
# ===============================================================================================================

# %% [markdown]
# # use hugging face
#
# #### API for Language Translation

# %% [markdown]
# ## T5  and mT5
#
#
# ## BERT -- Bidirectional Encoder Representations from Transformers
#
# ## BART and mBART (multilingual BART)
#
# ## XLM-R (Cross-lingual Language Model)
#
# ### MarianMT: MarianMT is a transformer-based machine translation model developed by the Marian NMT project
#
# ### Fairseq-based Models: Fairseq is a sequence-to-sequence toolkit developed by Facebook AI Research.

# %% [markdown]
# https://huggingface.co/t5-base

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/t5-base"   #ENGLISH TO GERMAN


headers = {"Authorization": "Bearer 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"}


#instead of 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, please generate and use your OWN TOKEN from huggingface as taught in last class

# %%
#Language(s) (NLP): English, French, Romanian, German

# %%
def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

# %%
output = query({
	"inputs": "My name is Sarah and I live in London",
})

# %%
output
# Out:
# {'error': 'Model t5-small is currently loading', 'estimated_time': 20.0}

# %% [markdown]
# ======================================================

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/t5-small"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "Меня зовут Вольфганг и я живу в Берлине",
})

# %%
output.
# Out:
# {'error': 'Model t5-small is currently loading', 'estimated_time': 20.0}

# %% [markdown]
# ======================================================
