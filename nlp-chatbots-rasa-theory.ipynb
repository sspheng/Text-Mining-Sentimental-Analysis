# %% [markdown]
# chatbots   ---->>>  website --FB --- whatsapp
# tech stack  --->> rasa  --- doalogflow --- low code wotnot   ---- chatgpt
# alogirthm -- RULE BASED --- ML BASED (GPT algortihm)
#
#
#
# PROMPT
#
# TEXT  ------  NLP model
#
# 1 Intent and Entity extraction
#
#
# Book cab for me  ---->>> clasification ----> booking cab
#
# NER --- NOUNS
#
# * cab
# * me (Rahul)
#
#
# DIALOG
#
# -->>  response (utterance vs action)
# ok, but tell me src and destination
#
#
# <<--
#
# Delhi  to Mumbai
#
# Sydney to Mebourne
#
# --->>
# tell me the time (utterenace)
#
#
# <<<----
#
# 6 PM today
#
# ---->> response (action)   ----> book and send
#
#
# --->>> cab is booked from Delhi  to Mumbai for 6 PM today

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pipelines:

# %% [markdown]
# Policies:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
