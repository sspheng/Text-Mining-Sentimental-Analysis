# %% [markdown]
# ## NLP - Building Chatbots
#
# https://guardiancoder.com/category/nlp/

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# ### There are different approaches to building a ChatBot:

# %% [markdown]
# 1. From Scratch using Rasa Framework and Python
# * https://rasa.com/

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# 2. Using Google DialogFlow
#
# * Its Config Based. We need to Define Intent and Entity for Bot Agents

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---------------------------------------------------
# * https://dialogflow.cloud.google.com/
# * https://dialogflow.cloud.google.com/cx/projects

# %% [markdown]
# --------------------------------
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# 3. Using low code Chatbot Platforms
#
# * Drift
# * Intercom
# * ChatFuel
# * WotNot  -- https://wotnot.io/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------------------------------------
#
# ## ChatGPT
#
# * https://openai.com/blog/chatgpt
# * https://chat.openai.com/

# %% [markdown]
# ## You can get a List of ChatBots based on GPT here -
#
# ### https://gpt3demo.com/
#
# * MetaGPT
# * AutoGPT
# * ChaosGPT
# * GraphGPT
# * ChartGPT
